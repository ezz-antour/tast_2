# %%
import pandas as pd

# %%
book=pd.read_csv('bl_flickr_images_book.csv')

# %%
book.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
book.rename(columns={'Edition Statement':'Edition_Statement'})
# Out:
#       Identifier             Edition_Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
book.rename(columns=lambda header: header.lower().replace(" ",'_'),inplace=True)

# %%
book.rename(columns={'identifier':'id'},inplace=True)

# %%
book.head(
    
)
# Out:
#     id             edition_statement      place_of_publication  \
# 0  206                           NaN                    London
# 1  216                           NaN  London; Virtue & Yorston
# 2  218                           NaN                    London
# 3  472                           NaN                    London
# 4  480  A new edition, revised, etc.                    London
#
#   date_of_publication              publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                title     author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
book.set_index('id',inplace=True)

# %%
book.head(
    
)
# Out:
#                 edition_statement      place_of_publication  \
# id
# 206                           NaN                    London
# 216                           NaN  London; Virtue & Yorston
# 218                           NaN                    London
# 472                           NaN                    London
# 480  A new edition, revised, etc.                    London
#
#     date_of_publication              publisher  \
# id
# 206         1879 [1878]       S. Tinsley & Co.
# 216                1868           Virtue & Co.
# 218                1869  Bradbury, Evans & Co.
# 472                1851          James Darling
# 480                1857   Wertheim & Macintosh
#
#                                                  title     author  \
# id
# 206                  Walter Forbes. [A novel.] By A. A      A. A.
# 216  All for Greed. [A novel. The dedication signed...  A., A. A.
# 218  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
book.loc[:,'date_of_publication']
# Out:
# id
# 206        1879 [1878]
# 216               1868
# 218               1869
# 472               1851
# 480               1857
#               ...
# 4158088           1838
# 4158128       1831, 32
# 4159563      [1806]-22
# 4159587           1834
# 4160339        1834-43
# Name: date_of_publication, Length: 8287, dtype: object

# %%
book.loc[:,'date_of_publication'].str.extract(r"(\d{4})")
# Out:
#             0
# id
# 206      1879
# 216      1868
# 218      1869
# 472      1851
# 480      1857
# ...       ...
# 4158088  1838
# 4158128  1831
# 4159563  1806
# 4159587  1834
# 4160339  1834
#
# [8287 rows x 1 columns]

# %%
book.loc[:,'date_of_publication'].str.extract(r"(\d{4})").fillna(0)
# Out:
#             0
# id
# 206      1879
# 216      1868
# 218      1869
# 472      1851
# 480      1857
# ...       ...
# 4158088  1838
# 4158128  1831
# 4159563  1806
# 4159587  1834
# 4160339  1834
#
# [8287 rows x 1 columns]

# %%
book.loc[:,'date_of_publication'].str.extract(r"(\d{4})").fillna(0).isna().sum()
# Out:
# 0    0
# dtype: int64

# %%
book.head()
# Out:
#                 edition_statement      place_of_publication  \
# id
# 206                           NaN                    London
# 216                           NaN  London; Virtue & Yorston
# 218                           NaN                    London
# 472                           NaN                    London
# 480  A new edition, revised, etc.                    London
#
#     date_of_publication              publisher  \
# id
# 206         1879 [1878]       S. Tinsley & Co.
# 216                1868           Virtue & Co.
# 218                1869  Bradbury, Evans & Co.
# 472                1851          James Darling
# 480                1857   Wertheim & Macintosh
#
#                                                  title     author  \
# id
# 206                  Walter Forbes. [A novel.] By A. A      A. A.
# 216  All for Greed. [A novel. The dedication signed...  A., A. A.
# 218  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
type(book.loc[:,'date_of_publication'].str.extract(r"(\d{4})",expand=False).fillna(0))
# Out:
# pandas.core.series.Series
